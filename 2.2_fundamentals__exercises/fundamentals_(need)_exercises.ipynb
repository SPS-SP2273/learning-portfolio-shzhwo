# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# #### Python features I rememebered:
# 1. f strings
# 2. "in" operator for checking membership
# 3. Conditionals
# 4. Arithmetic operators
# 5. Relational operators
#
# #### Python features I supplemented after consulting the notes:
# 1. Case sensitive
# 2. Supports commenting
# 3. "=" for assignment and "==" as a relational operator
# 4. Indentation
# 5. Packages
# 6. Supports a variety of data types
# 7. Deep copy using the copy() function

# %% [markdown]
# # Exercise 2

# %%
x, y = 3, 4
z = (x**2 + y**2) ** 0.5
print(x, y, z)
# Out:
# 3 4 5.0

# %% [markdown]
# # Exercise 3

# %% [markdown]
# |  # | Term         | Description |
# |:--:|--------------|:-----------|
# |  1 | Function     | Functions are abstracted chunks of code that run a pre-specified program on variable inputs |
# |  2 | Arguments    | Arguments are parameters provided to a function to be processed by the function for an output |
# |  3 | Comments     | Comments specify remarks usually for the ease of the coder or the reader to organise and understand the code |
# |  4 | Indentations | Indentation are spaces used to indicate the hierarchy of code in lieu of parentheses in Python |
# |  5 | Packages     | Packages are bundles of code that provide pre-made functions and tools which the user may use for their convenience |
# |  6 | `.`          | A period accesses attributes and methods of an object |
# |  7 | `:`          | A colon precedes a block of (indented) code with specifications on the conditions this code should be interpreted under |
# |  8 | `[]`         | This is an empty list |
# |  9 | `[[],[]]`    | This is a list containing two empty lists |
# | 10 | `{}`         | This is an empty set |

# %% [markdown]
# # Exercise 4

# %%
5/2           # Division

# %%
5//2          # Division rounded down to the nearest integer

# %%
5%2           # 5 - 2 * (5 // 2)
